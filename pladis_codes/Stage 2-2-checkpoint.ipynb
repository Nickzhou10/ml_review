# %%
# data analysis and wrangling
import scipy.stats
from IPython.core.display import HTML
import pandas as pd
import numpy as np
import statistics
from itertools import chain
# visualization
from IPython.core.display import HTML
from pandas.plotting import scatter_matrix
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from pprint import pprint
# %matplotlib inline
#plotly
import plotly.io as pio
import plotly.express as px
from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
import plotly as py 
import plotly.graph_objs as go # plotly graphical object
import plotly.io as pio
pio.renderers.default='notebook'
# setting the general visualization style
sns.set_style('whitegrid')
# feature engineering
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
#Libraries for Statistical Models
import statsmodels.api as sm
# ignoring warnings in the notebook
import warnings 
warnings.filterwarnings('ignore') 
# To display full output 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# feature engineering
import pandas_profiling as pp
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


# machine learning models\
from sklearn.linear_model import ElasticNetCV
from sklearn import datasets, linear_model
import statsmodels.api as sm
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVR
from sklearn.linear_model import Lasso,ElasticNet
# model selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# Tuning and Esembling
from sklearn.model_selection import GridSearchCV        
from sklearn.model_selection import RandomizedSearchCV 
from mlxtend.regressor import StackingCVRegressor

# %%
def plotly(name):
    df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
    fig = px.line(df[df['full_name']== name],
              x='date', y='price_per_unit', title='Price_per_units for '+ name,
              color='channel', template="none")
    fig.update_xaxes(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=1, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    )
    fig.show();

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
def plot_seasonal_dec(df,period,name,color): 
    df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
    df[df_ts['channel'] == 'Tesco Express']['Sales']
    res = seasonal_decompose(df, model = "additive", period = period)
    fig, axes = plt.subplots(4,1, figsize=(15,7), sharex=True)
    axes[0].set_title(name + 'seasonal decompose analysis', size =15)
    res.observed.plot(ax=axes[0], legend=False, color = color)
    axes[0].set_ylabel('observed', size=15)
    res.trend.plot(ax=axes[1], legend=False, color = color)
    axes[1].set_ylabel('trend', size=15)
    res.seasonal.plot(ax=axes[2], legend=False, color = color)
    axes[2].set_ylabel('seasoanlity', size=15)
    res.resid.plot(ax=axes[3], legend=False, color = color)
    axes[3].set_ylabel('residual', size=15)
    plt.show();

def plotly_canni(x1,x2,y1,y2,title1):
    import plotly.io as pio
    import plotly.express as px
    from plotly.subplots import make_subplots
    from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
    import plotly as py 
    import plotly.graph_objs as go # plotly graphical object
    import plotly.io as pio
    pio.renderers.default='notebook'
    df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
    df['units'] = df['Sales']/df['price_per_unit']
    df_x = df.loc[(df.full_name == x1)&(df.channel == x2)]
    df_y = df.loc[(df.full_name == y1)&(df.channel == y2)]
    x_t,x_p,x_u,x_d,x_m,x_k = df_x['date'],df_x['price_per_unit'],df_x['units'],df_x['distribution'],df_x['sub_index'],df_x['Sales']
    y_t,y_p,y_u,y_d,y_m,y_k = df_y['date'],df_y['price_per_unit'],df_y['units'],df_y['distribution'],df_y['sub_index'],df_y['Sales']

    fig = make_subplots(rows=5, cols=1)
    # Create and style traces
    fig.add_trace(go.Scatter(x=x_t, y=x_p, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_p, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_k, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_k, name= x1+', '+x2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_u, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=3, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_u, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=3, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_d, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=4, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_d, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=4, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_m, name = 'Subsegment',
                             line=dict(color='orange', width=1.5),showlegend=False), row=5, col=1)    
    fig.update_layout(title=title1,legend=dict(yanchor="top",y=1.13,xanchor="right",x=0.70,bgcolor = 'rgba(0,0,0,0)',font=dict(size=13)))
    
    fig.update_yaxes(title_text="Price per Unit", row=1, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Sales", row=2, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Units Sold", row=3, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Distribution", row=4, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Subsegment", row=5, col=1,title_font=dict(size=11))
    fig.show();

# %%
df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df['units'] = df['Sales']/df['price_per_unit']
df_x = df.loc[(df.full_name == 'JFF CKS DRK CHCLT & ORNG 244 GM SNGL')&(df.channel == 'Tesco excl. Express')]
df_y = df.loc[(df.full_name == 'JFF CKS DRK CHCLT & ORNG 122 GM SNGL')&(df.channel == 'Tesco excl. Express')]

# %%
def plotly_canni(x1,x2,y1,y2,title1):
    import plotly.io as pio
    import plotly.express as px
    from plotly.subplots import make_subplots
    from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
    import plotly as py 
    import plotly.graph_objs as go # plotly graphical object
    import plotly.io as pio
    pio.renderers.default='notebook'
    df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
    df['units'] = df['Sales']/df['price_per_unit']
    df_x = df.loc[(df.full_name == x1)&(df.channel == x2)]
    df_y = df.loc[(df.full_name == y1)&(df.channel == y2)]
    df_com = pd.DataFrame(columns=['Com','date'])
    df_com['date'] = df_x['date']
    df_com['Com'] = df_x['Sales'] + df_y['Sales']
    x_t,x_p,x_u,x_d,x_m,x_k = df_x['date'],df_x['price_per_unit'],df_x['units'],df_x['distribution'],df_x['sub_index'],df_x['Sales']
    y_t,y_p,y_u,y_d,y_m,y_k = df_y['date'],df_y['price_per_unit'],df_y['units'],df_y['distribution'],df_y['sub_index'],df_y['Sales']
    fig = make_subplots(rows=6, cols=1)
    # Create and style traces
    fig.add_trace(go.Scatter(x=x_t, y=x_p, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_p, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_k, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_k, name= x1+', '+x2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=df_com['Com'], name = 'Combined Sales',
                         line=dict(color='orange', width=1.5),showlegend=False), row=3, col=1) 
    fig.add_trace(go.Scatter(x=x_t, y=x_u, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=4, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_u, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=4, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_d, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=5, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_d, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=5, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_m, name = 'Subsegment',
                             line=dict(color='orange', width=1.5),showlegend=False), row=6, col=1)    
    fig.update_layout(title=title1,legend=dict(yanchor="top",y=1.13,xanchor="right",x=0.70,bgcolor = 'rgba(0,0,0,0)',font=dict(size=13)))
    
    fig.update_yaxes(title_text="Price per Unit", row=1, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Sales", row=2, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Combined Sales", row=3, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Units Sold", row=4, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Distribution", row=5, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Subsegment", row=6, col=1,title_font=dict(size=11))
    fig.show();

# %% [markdown]
# # Rank 1

# %%
ranks = pd.read_csv("/project/results/rankings.csv")

# %%
for i in ranks['Rank'].drop_duplicates().values.tolist():
    for j in ranks.loc[ranks.Rank == i,'Victims'].drop_duplicates().values.tolist():
        for k in ranks.loc[(ranks.Rank == i)&(ranks.Victims == j),'Victim channel'].drop_duplicates().values.tolist():
            for l in ranks.loc[(ranks.Rank == i)&(ranks.Victims == j)&(ranks['Victim channel'] == k),'cannibals'].drop_duplicates().values.tolist():
                for z in ranks.loc[(ranks.Rank == i)&(ranks.Victims == j)&(ranks['Victim channel'] == k)&(ranks.cannibals == l),'cannibal channel'].drop_duplicates().values.tolist():
                    plotly_canni(x1 = j,x2 = k,y1 = l,y2 = z,title1 = i)

# %%
plotly_canni(x1 = 'MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK',
             x2 = 'Tesco excl. Express',
             y1 = 'TWX FNGRS CRML & SHRTCK 23 GM 9 PCK',
             y2 = 'Tesco excl. Express', title1 = 'Compeition Rank 1')

# %%
plotly_canni(x1 = 'MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK',
             x2 = 'Tesco Express',
             y1 = 'TWX FNGRS CRML & SHRTCK 23 GM 9 PCK',
             y2 = 'Tesco Express', title1 = 'Compeition Rank 2')

# %%
plotly_canni(x1 = 'MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL',
             x2 = 'Tesco excl. Express',
             y1 = 'TRTS OTHR CRM OR CKS VNLL 154 GM SNGL',
             y2 = 'Tesco excl. Express',title1='Compeition Rank 3')

# %%
plotly_canni(x1 = 'GNGR MCVTS GNGR NTS GNGR 250 GM SNGL',
             x2 = 'Tesco Express',
             y1 = 'GNGR MCVTS GNGR NTS GNGR 250 GM SNGL',
             y2 = 'Tesco excl. Express',title1 = '')

# %%
def plotly_canni(x1,x2,y1,y2,title1):
    import plotly.io as pio
    import plotly.express as px
    from plotly.subplots import make_subplots
    from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
    import plotly as py 
    import plotly.graph_objs as go # plotly graphical object
    import plotly.io as pio
    pio.renderers.default='notebook'
    df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
    df['units'] = df['Sales']/df['price_per_unit']
    df_x = df.loc[(df.full_name == x1)&(df.channel == x2)]
    df_y = df.loc[(df.full_name == y1)&(df.channel == y2)]
    x_t,x_p,x_u,x_d,x_k = df_x['date'],df_x['price_per_unit'],df_x['units'],df_x['distribution'],df_x['Sales']
    y_t,y_p,y_u,y_d,y_k = df_y['date'],df_y['price_per_unit'],df_y['units'],df_y['distribution'],df_y['Sales']

    fig = make_subplots(rows=4, cols=1)
    # Create and style traces
    fig.add_trace(go.Scatter(x=x_t, y=x_p, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_p, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5)), row=1, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_k, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_k, name= x1+', '+x2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=2, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_u, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=3, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_u, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=3, col=1)
    fig.add_trace(go.Scatter(x=x_t, y=x_d, name= x1+', '+x2,
                             line=dict(color='firebrick', width=1.5),showlegend=False), row=4, col=1)
    fig.add_trace(go.Scatter(x=y_t, y=y_d, name = y1+', '+y2,
                             line=dict(color='royalblue', width=1.5),showlegend=False), row=4, col=1)   
    fig.update_layout(title=title1,legend=dict(yanchor="top",y=1.13,xanchor="right",x=0.70,bgcolor = 'rgba(0,0,0,0)',font=dict(size=13)))
    
    fig.update_yaxes(title_text="Price per Unit", row=1, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Sales", row=2, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Units Sold", row=3, col=1,title_font=dict(size=11))
    fig.update_yaxes(title_text="Distribution", row=4, col=1,title_font=dict(size=11))
    fig.show();

# %%
plotly_canni(x1 = 'JFF CKS DRK CHCLT & ORNG 244 GM SNGL',
             x2 = 'Sainsbury excl Local',
             y1 = 'JFF CKS DRK CHCLT & ORNG 244 GM SNGL',
             y2 = 'Sainsbury Local','Figure 7: Plots of Numerical features of a product by channels')

# %%
plotly_canni(x1 = 'JFF CKS DRK CHCLT & ORNG 244 GM SNGL',
             x2 = 'Tesco Express',
             y1 = 'JFF CKS DRK CHCLT & ORNG 244 GM SNGL',
             y2 = 'Tesco excl. Express')
