# %%
import sys
# !{sys.executable} -m pip install pandas-profiling

# %%
conda install qgrid
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade category_encoders
# Out:
#          .:::.     .::.
#         ....yy:    .yy.
#         :.  .yy.    y.
#              :y:   .:
#              .yy  .:
#               yy..:
#               :y:.
#               .y.
#              .:.
#         ....:.
#         :::.
#
# • Project files and data should be stored in /project. This is shared among everyone
#   in the project.
# • Personal files and configuration should be stored in /home/faculty.
# • Files outside /project and /home/faculty will be lost when this server is terminated.
# • Create custom environments to setup your servers reproducibly.
#
# Requirement already satisfied: category_encoders in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (1.18.5)
# Requirement already satisfied: patsy>=0.5.1 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=0.21.1 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda/envs/Python3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# data analysis and wrangling
from IPython.core.display import HTML
import pandas as pd
import numpy as np
import statistics
from itertools import chain
# visualization
from pandas.plotting import scatter_matrix
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from pprint import pprint
# %matplotlib inline
#plotly
import plotly.io as pio
import plotly.express as px
from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
import plotly as py 
import plotly.graph_objs as go # plotly graphical object
import plotly.io as pio
pio.renderers.default='notebook'
# setting the general visualization style
sns.set_style('whitegrid')
# feature engineering
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
#Libraries for Statistical Models
import statsmodels.api as sm
# ignoring warnings in the notebook
import warnings 
warnings.filterwarnings('ignore') 
# To display full output 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# feature engineering
import pandas_profiling as pp
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# machine learning models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVR
from xgboost import XGBRegressor

# model selection
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# Tuning and Esembling
from sklearn.model_selection import GridSearchCV        
from sklearn.model_selection import RandomizedSearchCV 
from mlxtend.regressor import StackingCVRegressor

# %%
df_sku = pd.read_csv("/project/data_for_models/df_final.csv",index_col=0)

#df_sku['date'] = pd.to_datetime(df_sku['date'])
#df_sub['date'] = pd.to_datetime(df_sub['date'])
#df_mkt['date'] = pd.to_datetime(df_mkt['date'])
df_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18986 entries, 0 to 18985
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   full_name        18986 non-null  object
#  1   brand            18986 non-null  object
#  2   company          18986 non-null  object
#  3   Subsegment       18986 non-null  object
#  4   flavour          18986 non-null  object
#  5   pack_type        18986 non-null  object
#  6   weight           18986 non-null  object
#  7   channel          18986 non-null  object
#  8   retailer         18986 non-null  object
#  9   format           18986 non-null  object
#  10  date             18986 non-null  object
#  11  Year             18986 non-null  int64
#  12  WeekOfYear       18986 non-null  int64
#  13  Month            18986 non-null  int64
#  14  Sales            18986 non-null  float64
#  15  distribution     18986 non-null  float64
#  16  price_per_kg     18986 non-null  float64
#  17  price_per_unit   18986 non-null  float64
#  18  promo            18986 non-null  int64
#  19  Cum.promo.total  18986 non-null  int64
#  20  base_price1      18986 non-null  float64
#  21  Promo_depth      18986 non-null  float64
# dtypes: float64(6), int64(5), object(11)
# memory usage: 3.3+ MB

# %% [markdown]
# # Checking data classes

# %%
subseg = df_sku.groupby(['Subsegment'], as_index=False)
subseg = subseg.agg({"full_name": "nunique"})
subseg = subseg.sort_values(['full_name']).reset_index(drop=True)
subseg.rename(columns={'full_name':'No.products under the category'}, inplace=True)
subseg
brand = df_sku.groupby(['brand'], as_index=False)
brand = brand.agg({"full_name": "nunique"})
brand = brand.sort_values(['full_name']).reset_index(drop=True)
brand.rename(columns={'full_name':'No.products under the category'}, inplace=True)
brand
flavour = df_sku.groupby(['flavour'], as_index=False)
flavour = flavour.agg({"full_name": "nunique"})
flavour = flavour.sort_values(['full_name']).reset_index(drop=True)
flavour.rename(columns={'full_name':'No.products under the category'}, inplace=True)
flavour
pack_type = df_sku.groupby(['pack_type'], as_index=False)
pack_type = pack_type.agg({"full_name": "nunique"})
pack_type = pack_type.sort_values(['full_name']).reset_index(drop=True)
pack_type.rename(columns={'full_name':'No.products under the category'}, inplace=True)
pack_type
weight = df_sku.groupby(['weight'], as_index=False)
weight = weight.agg({"full_name": "nunique"})
weight = weight.sort_values(['full_name']).reset_index(drop=True)
weight.rename(columns={'full_name':'No.products under the category'}, inplace=True)
weight
company = df_sku.groupby(['company'], as_index=False)
company = company.agg({"full_name": "nunique"})
company = company.sort_values(['full_name']).reset_index(drop=True)
company.rename(columns={'full_name':'No.products under the category'}, inplace=True)
company
# Out:
#   Subsegment  No.products under the category
# 0        CBB                               5
# 1        EDB                               9
# 2  Healthier                               9
# 3        EDT                              11
#                               brand  No.products under the category
# 0      BELVITA BREAKFAST DUO CRUNCH                               1
# 1                        OREO THINS                               1
# 2                      OREO COOKIES                               1
# 3        NATURE VALLEY PROTEIN BARS                               1
# 4        NATURE VALLEY CRUNCHY BARS                               1
# 5                 MCVITIES RICH TEA                               1
# 6                  MCVITIES PENGUIN                               1
# 7                  MCVITIES HOBNOBS                               1
# 8              MCVITIES GINGER NUTS                               1
# 9               MCVITIES DIGESTIVES                               1
# 10                    MCVITIES CLUB                               1
# 11       MCVITIES CHOCOLATE HOBNOBS                               1
# 12                    LOTUS BISCOFF                               1
# 13   KELLOGGS RICE KRISPIES SQUARES                               1
# 14           KELLOGGS COCO POPS BAR                               1
# 15                    FOXS VIENNESE                               1
# 16                FOXS JAM 'N CREAM                               1
# 17               FOXS CRUNCH CREAMS                               1
# 18  EAT NATURAL PROTEIN PACKED BARS                               1
# 19               CADBURY BRUNCH BAR                               1
# 20                 MARYLAND COOKIES                               1
# 21                     TWIX FINGERS                               1
# 22    MCVITIES CHOCOLATE DIGESTIVES                               2
# 23                          KIT KAT                               2
# 24             MCVITIES JAFFA CAKES                               2
# 25     BELVITA BREAKFAST SOFT BAKES                               2
# 26                    PRIVATE LABEL                               4
#                      flavour  No.products under the category
# 0                  BLUEBERRY                               1
# 1                  RASPBERRY                               1
# 2                   ORIGINAL                               1
# 3                     ORANGE                               1
# 4               OATS & HONEY                               1
# 5                MARSHMALLOW                               1
# 6                MALTED MILK                               1
# 7   STRAWBERRY & LIVE YOGURT                               1
# 8                     GINGER                               1
# 9                     GOLDEN                               1
# 10                   CUSTARD                               1
# 11                CHOC CHIPS                               1
# 12               CARAMELISED                               1
# 13       CARAMEL & SHORTCAKE                               1
# 14                       FIG                               1
# 15   DARK CHOCOLATE & ORANGE                               2
# 16            DARK CHOCOLATE                               2
# 17            CHOCOLATE CHIP                               2
# 18                 CHOCOLATE                               2
# 19        PEANUT & CHOCOLATE                               2
# 20                   VANILLA                               2
# 21                     PLAIN                               3
# 22            MILK CHOCOLATE                               4
#   pack_type  No.products under the category
# 0    3 PACK                               1
# 1    4 PACK                               2
# 2    6 PACK                               2
# 3    8 PACK                               2
# 4    9 PACK                               3
# 5    5 PACK                               4
# 6    SINGLE                              20
#      weight  No.products under the category
# 0    120 GM                               1
# 1     45 GM                               1
# 2     42 GM                               1
# 3     40 GM                               1
# 4     32 GM                               1
# 5     28 GM                               1
# 6    262 GM                               1
# 7    244 GM                               1
# 8     23 GM                               1
# 9   24.6 GM                               1
# 10    21 GM                               1
# 11  20.7 GM                               1
# 12    20 GM                               1
# 13   192 GM                               1
# 14   154 GM                               1
# 15   150 GM                               1
# 16   122 GM                               1
# 17    22 GM                               1
# 18    51 GM                               1
# 19   230 GM                               2
# 20    50 GM                               2
# 21   250 GM                               2
# 22   266 GM                               2
# 23   300 GM                               2
# 24   400 GM                               2
# 25   200 GM                               3
#                    company  No.products under the category
# 0         BURTONS BISCUITS                               1
# 1              EAT NATURAL                               1
# 2           LOTUS BAKERIES                               1
# 3                     MARS                               1
# 4            GENERAL MILLS                               2
# 5                 KELLOGGS                               2
# 6          NESTLE ROWNTREE                               2
# 7            FOXS BISCUITS                               3
# 8            PRIVATE LABEL                               4
# 9   MONDELEZ INTERNATIONAL                               6
# 10               PLADIS UK                              11

# %%
f, axes = plt.subplots(1, 3, sharex=True, figsize=(26,13))
sns.barplot(y="brand", x= "No.products under the category",
            data=brand,  orient='h', palette="light:#5A9" , linewidth = 1, ax=axes[0]);
sns.barplot(y="weight", x= "No.products under the category",
            data=weight,  orient='h',palette='ch:s=.25,rot=-.25' , linewidth = 1, ax=axes[1]);
sns.barplot(y="flavour", x= "No.products under the category",
            data=flavour,  orient='h', palette='OrRd' , linewidth = 1, ax=axes[2]);
axes[0].set_title('Number of individual products by brands', fontsize=18);
axes[1].set_title('Number of individual products by weight', fontsize=18);
axes[2].set_title('Number of individual products by flavours', fontsize=18);
f.savefig("/project/figures/subplots1.png");

f, axes = plt.subplots(1, 3, sharex=True, figsize=(18,9))
sns.barplot(y="company", x= "No.products under the category",
            data=company,  orient='h',palette='light:#5A9' , ax=axes[0]);
sns.barplot(y="pack_type", x= "No.products under the category",
            data=pack_type,  orient='h', palette='ch:s=.25,rot=-.25' , ax=axes[1]);
sns.barplot(y="Subsegment", x= "No.products under the category",
            data=subseg,  orient='h',palette='OrRd' , ax=axes[2]);
axes[0].set_title('Number of individual products by manufacturing company', fontsize=13);
axes[1].set_title('Number of individual products by pack types', fontsize=13);
axes[2].set_title('Number of individual products by Biscuit subsegments', fontsize=13);
f.savefig("/project/figures/subplots2.png");

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## covid features

# %%
# covid
df_sku.loc[(df_sku.date < '2020-02-28'),'covid']='No Covid'
df_sku.loc[(df_sku.date >= '2020-02-28')&(df_sku.date<'2020-03-26'),'covid']='prior to lockdown'
df_sku.loc[(df_sku.date >= '2020-03-26')&(df_sku.date<'2020-05-10'),'covid']='1st lockdown'
df_sku.loc[(df_sku.date >= '2020-05-10')&(df_sku.date<'2020-09-14'),'covid']='easing period'
df_sku.loc[(df_sku.date >= '2020-09-14'),'covid']='2nd lockdown'

# %% [markdown]
# ## Time features

# %%
#winter: 15th January to 15th March
df_sku.loc[(df_sku.date > '2019-01-15') & (df_sku.date <= '2019-03-15'),'seasons']='Winter'
df_sku.loc[(df_sku.date > '2020-01-15') & (df_sku.date <= '2020-03-15'),'seasons']='Winter'
df_sku.loc[(df_sku.date > '2021-01-15') & (df_sku.date <= '2021-03-15'),'seasons']='Winter'
#spring: 15th March to 15th May
df_sku.loc[(df_sku.date > '2019-03-15') & (df_sku.date <= '2019-05-15'),'seasons']='Spring'
df_sku.loc[(df_sku.date > '2020-03-15') & (df_sku.date <= '2020-05-15'),'seasons']='Spring'
df_sku.loc[(df_sku.date > '2021-03-15') & (df_sku.date <= '2021-05-15'),'seasons']='Spring'
#Summer: 15th May to 15th August 
df_sku.loc[(df_sku.date > '2018-05-15') & (df_sku.date <= '2018-08-15'),'seasons']='Summer'
df_sku.loc[(df_sku.date > '2019-05-15') & (df_sku.date <= '2019-08-15'),'seasons']='Summer'
df_sku.loc[(df_sku.date > '2020-05-15') & (df_sku.date <= '2020-08-15'),'seasons']='Summer'
# Autumn: 15th August to 15th December
df_sku.loc[(df_sku.date > '2018-08-15') & (df_sku.date <= '2018-12-15'),'seasons']='Autumn'
df_sku.loc[(df_sku.date > '2019-08-15') & (df_sku.date <= '2019-12-15'),'seasons']='Autumn'
df_sku.loc[(df_sku.date > '2020-08-15') & (df_sku.date <= '2020-12-15'),'seasons']='Autumn'

df_sku.loc[(df_sku.date > '2018-12-15') & (df_sku.date <= '2019-01-15'),'seasons']='christmas'
df_sku.loc[(df_sku.date > '2019-12-15') & (df_sku.date <= '2020-01-15'),'seasons']='christmas'
df_sku.loc[(df_sku.date > '2020-12-15') & (df_sku.date <= '2021-01-15'),'seasons']='christmas'
df_sku.to_csv("/project/data_for_models/feature_eng1.csv") 
df_sku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18986 entries, 0 to 18985
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   full_name        18986 non-null  object
#  1   brand            18986 non-null  object
#  2   company          18986 non-null  object
#  3   Subsegment       18986 non-null  object
#  4   flavour          18986 non-null  object
#  5   pack_type        18986 non-null  object
#  6   weight           18986 non-null  object
#  7   channel          18986 non-null  object
#  8   retailer         18986 non-null  object
#  9   format           18986 non-null  object
#  10  date             18986 non-null  object
#  11  Year             18986 non-null  int64
#  12  WeekOfYear       18986 non-null  int64
#  13  Month            18986 non-null  int64
#  14  Sales            18986 non-null  float64
#  15  distribution     18986 non-null  float64
#  16  price_per_kg     18986 non-null  float64
#  17  price_per_unit   18986 non-null  float64
#  18  promo            18986 non-null  int64
#  19  Cum.promo.total  18986 non-null  int64
#  20  base_price1      18986 non-null  float64
#  21  Promo_depth      18986 non-null  float64
#  22  covid            18986 non-null  object
#  23  seasons          18986 non-null  object
# dtypes: float64(6), int64(5), object(13)
# memory usage: 3.6+ MB

# %% [markdown]
# # Dependent variable

# %% [markdown]
# ## mkt index & subsegment index

# %%
df_sku = pd.read_csv("/project/data_for_models/feature_eng1.csv",index_col=0)
df_sub = pd.read_csv("/project/raw_data/Biscuit_subsegments.csv",index_col=0)
df_mkt = pd.read_csv("/project/raw_data/Sweet_Biscuits.csv",index_col=0)
df_mkt.rename(columns={'price_per_unit':'price_per_unit_mkt'}, inplace=True)
df_sub.rename(columns={'price_per_unit':'price_per_unit_sub'}, inplace=True)
df_mkt = df_mkt[['channel','date','Sales','price_per_unit_mkt']]
df_sub = df_sub[['channel','date','subsegments','Sales','price_per_unit_sub']]
def create_retailer(df):
    df.loc[(df.channel == 'Tesco'),'retailer']='Tesco'
    df.loc[(df.channel == 'SSL'),'retailer']='Sainsbury'
    df.dropna(inplace=True)
    df.drop(['channel'], axis=1,inplace=True)
create_retailer(df_mkt)
create_retailer(df_sub)
df_mkt.rename(columns={'Sales':'mkt_index'}, inplace=True)
df_sub.rename(columns={'Sales':'sub_index'}, inplace=True)
df_sub.rename(columns={'subsegments':'Subsegment'}, inplace=True)
df_sub.loc[(df_sub['Subsegment'] == 'HEALTHIER BISCUITS'),'Subsegment']='Healthier'
df_sub.loc[(df_sub['Subsegment'] == 'CHOCOLATE BISCUIT BARS'),'Subsegment']='CBB'
df_sub.loc[(df_sub['Subsegment'] == 'EVERYDAY TREATS'),'Subsegment']='EDT'
df_sub.loc[(df_sub['Subsegment'] == 'EVERYDAY BISCUITS'),'Subsegment']='EDB'
df_mkt
df_sub
# Out:
#             date   mkt_index  price_per_unit_mkt   retailer
# 563   2015-12-12  10767636.0            1.142589      Tesco
# 564   2015-12-19  11461798.0            1.232900      Tesco
# 565   2015-12-26   9317565.0            1.338804      Tesco
# 566   2016-01-02   5047812.0            1.087640      Tesco
# 567   2016-01-09   7552686.0            1.070831      Tesco
# ...          ...         ...                 ...        ...
# 1120  2021-03-27   6168812.5            1.158040  Sainsbury
# 1121  2021-04-03   5930880.5            1.170299  Sainsbury
# 1122  2021-04-10   5037908.0            1.170208  Sainsbury
# 1123  2021-04-17   5616513.0            1.182361  Sainsbury
# 1124  2021-04-24   5913080.5            1.190434  Sainsbury
#
# [562 rows x 4 columns]
#             date Subsegment  sub_index  price_per_unit_sub   retailer
# 2249  2015-12-12        CBB  1545812.9            1.008219      Tesco
# 2250  2015-12-19        CBB  1357555.8            1.029264      Tesco
# 2251  2015-12-26        CBB   834782.8            1.058770      Tesco
# 2252  2016-01-02        CBB   566213.1            1.107674      Tesco
# 2253  2016-01-09        CBB  1004251.1            1.213858      Tesco
# ...          ...        ...        ...                 ...        ...
# 4492  2021-03-27  Healthier  2133704.5            1.407081  Sainsbury
# 4493  2021-04-03  Healthier  1971253.8            1.408526  Sainsbury
# 4494  2021-04-10  Healthier  1743384.4            1.396798  Sainsbury
# 4495  2021-04-17  Healthier  1894611.3            1.434302  Sainsbury
# 4496  2021-04-24  Healthier  2043693.8            1.474011  Sainsbury
#
# [2248 rows x 5 columns]

# %%
df_sku = pd.merge(df_sku, df_mkt, on=['retailer','date'], how='left')
df_sku = pd.merge(df_sku, df_sub, on=['retailer','date','Subsegment'], how='left')
df_sku.dropna(inplace=True)
df_sku.describe()
df_sku.to_csv("/project/data_for_models/feature_eng2.csv")
# Out:
#                Year    WeekOfYear         Month          Sales  distribution  \
# count  18620.000000  18620.000000  18620.000000   18620.000000  18620.000000
# mean    2019.356284     26.888614      6.550161   30295.216669      0.896513
# std        0.930890     15.263127      3.479480   30416.926149      0.185964
# min     2018.000000      1.000000      1.000000     653.000000      0.210000
# 25%     2019.000000     13.000000      3.000000   10812.875000      0.910000
# 50%     2019.000000     27.000000      7.000000   21212.700000      0.990000
# 75%     2020.000000     40.000000     10.000000   39769.900000      1.000000
# max     2021.000000     53.000000     12.000000  451881.900000      1.000000
#
#        price_per_kg  price_per_unit         promo  Cum.promo.total  \
# count  18620.000000    18620.000000  18620.000000     18620.000000
# mean       6.616888        1.301799      0.412352         1.222556
# std        3.919162        0.597468      0.492271         2.245592
# min        0.900000        0.290000      0.000000         0.000000
# 25%        3.987500        1.000000      0.000000         0.000000
# 50%        5.488000        1.125000      0.000000         0.000000
# 75%        8.454000        1.600000      1.000000         2.000000
# max       20.090000        3.109000      1.000000        24.000000
#
#         base_price1   Promo_depth     mkt_index  price_per_unit_mkt  \
# count  18620.000000  18620.000000  1.862000e+04        18620.000000
# mean       1.562230      0.147763  8.405426e+06            1.106379
# std        0.642014      0.192700  2.503667e+06            0.100400
# min        0.361000      0.000000  3.325695e+06            0.958425
# 25%        1.000000      0.000000  5.913080e+06            1.029943
# 50%        1.585000      0.000000  9.252868e+06            1.088408
# 75%        1.989000      0.333333  1.064234e+07            1.163061
# max        3.109000      0.643929  1.485611e+07            1.590172
#
#           sub_index  price_per_unit_sub
# count  1.862000e+04        18620.000000
# mean   1.752535e+06            1.048940
# std    8.537088e+05            0.250356
# min    2.204704e+05            0.588765
# 25%    1.087258e+06            0.847653
# 50%    1.549379e+06            1.051447
# 75%    2.225816e+06            1.289282
# max    4.654576e+06            1.547739

# %%
group = df_sku.groupby(['full_name'], as_index=False)
group = group.agg({"date": "nunique"})
group
# Out:
#                                    full_name  date
# 0      BLVT-BRKFST-SFT-BKS BLBRR 50 GM 5 PCK   146
# 1   BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK   153
# 2    BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK   153
# 3     BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK   153
# 4     BRS KLLGGS CC PPS BR CHCLT 20 GM 6 PCK   153
# 5   BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK   153
# 6   BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL   153
# 7      BSCTS FG RLLS PRVT LBL FG 200 GM SNGL   153
# 8   BSCTS MLTD PRVT LBL MLTD MLK 200 GM SNGL   153
# 9      BSCTS OTS MCVTS-HBNBS PLN 300 GM SNGL   153
# 10   BSCTS RCH T MCVTS RCH T PLN 300 GM SNGL   153
# 11       CKS MRLND CKS CHCLT CHP 230 GM SNGL   153
# 12     CSTRD CRMS PRVT LBL CSTRD 400 GM SNGL   153
# 13     CTD-CBB KT KT DRK CHCLT 20.7 GM 9 PCK   153
# 14  EVRD TRTS CKS PRVT LBL CHCLT 200 GM SNGL   153
# 15      GNGR MCVTS GNGR NTS GNGR 250 GM SNGL   153
# 16      JFF CKS DRK CHCLT & ORNG 122 GM SNGL   153
# 17      JFF CKS DRK CHCLT & ORNG 244 GM SNGL   153
# 18  MCVTS CHCLT DGSTVS DRK CHCLT 266 GM SNGL   153
# 19  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL   153
# 20   MCVTS-CHCLT-HBNBS MLK CHCLT 262 GM SNGL   153
# 21        MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK   153
# 22    NTR-VLL-CRNCH-BRS OTS & HN 42 GM 5 PCK   153
# 23  NTR-VLL-PRTN-BRS PNT & CHCLT 40 GM 4 PCK   153
# 24  OTHR CRM FXS CRNCH CRMS GLDN 230 GM SNGL   153
# 25   OTHR CRM FXS-VNNS MLK CHCLT 120 GM SNGL   153
# 26                   PNT & CHCLT 45 GM 3 PCK   153
# 27        RC KRSPS SQRS MRSHMLLW 28 GM 4 PCK   153
# 28               STRWBRR&LV-YGRT 51 GM 5 PCK   153
# 29    SWT BSCTS LTS-BSCFF CRMLSD 250 GM SNGL   153
# 30   TRTS JM FXS-JM'N-CRM RSPBRR 150 GM SNGL   153
# 31     TRTS OTHR CRM OR CKS VNLL 154 GM SNGL   153
# 32    TRTS OTHR CRM OR-THNS VNLL 192 GM SNGL   145
# 33       TWX FNGRS CRML & SHRTCK 23 GM 9 PCK   153

# %%
df_sku = pd.read_csv("/project/data_for_models/feature_eng2.csv",index_col=0)
channel = ['Tesco Express','Tesco excl. Express','Sainsbury Local','Sainsbury excl Local']
df_sku['Sales_p'] = df_sku['Sales']
df_sku['mkt_index_p'] = df_sku['mkt_index']
df_sku['sub_index_p'] = df_sku['sub_index']
for name in group['full_name'].values.tolist():
    for i in channel:
        df_sku.loc[(df_sku.full_name == name)&
                   (df_sku.channel == i),['Sales_p','mkt_index_p','sub_index_p']] = df_sku.loc[(df_sku.full_name == name)&
                   (df_sku.channel == i),['Sales_p','mkt_index_p','sub_index_p']].pct_change(fill_method='ffill')
df_sku.dropna(inplace=True)
df_sku['Excess_sales_mkt'] = df_sku['Sales_p'] - df_sku['mkt_index_p']
df_sku['Excess_sales_sub'] = df_sku['Sales_p'] - df_sku['sub_index_p']

# %%
def distribution(variable):
    fig, ax = plt.subplots(figsize=(13,5));
    df_sku[variable].hist(bins=40, ax=ax);
    ax.set_title("Histogram of " + variable, fontsize=16)
    ax.set_xlabel(variable, fontsize=12);
    ax.set_ylabel("Counts", fontsize=12);
distribution('Excess_sales_mkt')
distribution('Excess_sales_sub')
df_sku.describe()
df_sku.to_csv("/project/data_for_models/feature_eng3.csv")
# Out:
#                Year    WeekOfYear         Month          Sales  distribution  \
# count  18498.000000  18498.000000  18498.000000   18498.000000  18498.000000
# mean    2019.365229     26.924965      6.559736   30283.081439      0.896525
# std        0.927394     15.306199      3.488754   30428.927645      0.185916
# min     2018.000000      1.000000      1.000000     653.000000      0.210000
# 25%     2019.000000     13.000000      3.000000   10804.325000      0.910000
# 50%     2019.000000     28.000000      7.000000   21199.250000      0.990000
# 75%     2020.000000     40.000000     10.000000   39753.000000      1.000000
# max     2021.000000     53.000000     12.000000  451881.900000      1.000000
#
#        price_per_kg  price_per_unit         promo  Cum.promo.total  \
# count  18498.000000    18498.000000  18498.000000     18498.000000
# mean       6.618767        1.302136      0.411342         1.226889
# std        3.920772        0.597533      0.492090         2.251990
# min        0.900000        0.290000      0.000000         0.000000
# 25%        3.986000        1.000000      0.000000         0.000000
# 50%        5.490500        1.126000      0.000000         0.000000
# 75%        8.454000        1.600000      1.000000         2.000000
# max       20.090000        3.109000      1.000000        24.000000
#
#         base_price1   Promo_depth     mkt_index  price_per_unit_mkt  \
# count  18498.000000  18498.000000  1.849800e+04        18498.000000
# mean       1.562098      0.147489  8.405381e+06            1.106697
# std        0.642020      0.192702  2.504180e+06            0.100547
# min        0.361000      0.000000  3.325695e+06            0.958425
# 25%        1.000000      0.000000  5.914738e+06            1.030303
# 50%        1.585000      0.000000  9.252868e+06            1.088408
# 75%        1.989000      0.333333  1.059272e+07            1.163061
# max        3.109000      0.643929  1.485611e+07            1.590172
#
#           sub_index  price_per_unit_sub       Sales_p   mkt_index_p  \
# count  1.849800e+04        18498.000000  18498.000000  18498.000000
# mean   1.752126e+06            1.049196      0.103390      0.006800
# std    8.530773e+05            0.250383      0.658791      0.107673
# min    2.204704e+05            0.588765     -0.874622     -0.578556
# 25%    1.087258e+06            0.847653     -0.114604     -0.024495
# 50%    1.549379e+06            1.051447     -0.001693      0.007032
# 75%    2.227458e+06            1.289282      0.124209      0.042338
# max    4.654576e+06            1.547739     16.037460      0.502275
#
#         sub_index_p  Excess_sales_mkt  Excess_sales_sub
# count  18498.000000      18498.000000      18498.000000
# mean       0.009107          0.096590          0.094284
# std        0.138722          0.649598          0.637583
# min       -0.587134         -1.067067         -1.531972
# 25%       -0.037272         -0.101436         -0.091127
# 50%        0.001197         -0.006409         -0.001252
# 75%        0.040696          0.098900          0.087854
# max        1.389974         15.535185         15.154758

# %% [markdown]
# ## Dependent variable for promo efficiency

# %%
#df_sku = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
#df_sku.loc[df.promo == 1,'Promo_Efficiency_index_sub'] = df['Excess_sales_sub']/(1+df['Promo_depth'])
#df_sku.loc[df.promo == 0,'Promo_Efficiency_index_sub'] = 0
#df_sku.loc[df.promo == 1,'Promo_Efficiency_index_mkt'] = df['Excess_sales_mkt']/(1+df['Promo_depth'])
#df_sku.loc[df.promo == 0,'Promo_Efficiency_index_mkt'] = 0
#df_sku.to_csv("/project/data_for_models/feature_eng3.csv")

# %%
#plot1 = df_sku.groupby(['channel'], as_index=False)["Promo_Efficiency_index_sub"].mean()
#plot1

# %% [markdown]
# # continuous features

# %%
from sklearn.preprocessing import RobustScaler
from statsmodels.graphics.gofplots import qqplot
from scipy import stats
from scipy.stats import norm, skew,probplot #for some statistics
from scipy.special import boxcox1p

# %%
df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df = df.drop(['mkt_index','sub_index','Sales_p','mkt_index_p','sub_index_p'],axis=1)

# %%
df['weight'] = df['weight'].str.replace(r'GM$', '')
df['weight'] = df['weight'].astype(str).astype(float)

# %% [markdown]
# ## skewness

# %%
numeric_feats = df.dtypes[df.dtypes == "float"].index

# Check the skew of all numerical features
skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(120)
# Out:
# Skew in numerical features:
#                         Skew
# Excess_sales_sub    5.950974
# Excess_sales_mkt    5.929002
# Sales               3.133516
# price_per_unit_mkt  1.394301
# price_per_kg        1.273233
# price_per_unit      0.924642
# Promo_depth         0.769974
# base_price1         0.359304
# weight              0.279649
# price_per_unit_sub -0.129572
# distribution       -2.017044

# %%
def box_cox(example,lam_num):
    fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16, 16))
    plt.subplots_adjust(top=1.5, right=1.5)
    sns.distplot(df[example].dropna(), hist=True, ax=axs[0][0]);
    probplot(df[example].dropna(), plot=axs[0][1]);
    print('Original Sales to Market Skew: {}'.format(df[example].skew()));
    print('Original Excess sales to Market Kurtosis: {}'.format(df[example].kurt()));
    #df['Excess_sales_mkt'] = np.log1p(df['Excess_sales_mkt'])
    #df['Excess_sales_sub'] = np.log1p(df['Excess_sales_sub'])
    numeric_feats = df.dtypes[df.dtypes == "float"].index

    # Check the skew of all numerical features
    skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
    print("\nSkew in numerical features: \n")
    skewness = pd.DataFrame({'Skew' :skewed_feats})
    skewness = skewness[abs(skewness) > 0.75].dropna()
    skewness = skewness.drop(['Excess_sales_sub','Excess_sales_mkt','distribution'])
    print("There are {} skewed numerical features to Box Cox transform".format(skewness.shape[0]))
    skewed_features = skewness.index
    for feat in skewed_features:
        #df[feat] += 1
        df[feat] = boxcox1p(df[feat], lam_num)

    sns.distplot(df[example].dropna(), hist=True, ax=axs[1][0]);
    probplot(df[example].dropna(), plot=axs[1][1]);

    axs[0][0].set_xlabel(example +' to Market', size=20, labelpad=12.5)
    axs[1][0].set_xlabel(example +' to Market', size=20, labelpad=12.5)
    axs[0][1].set_xlabel('Theoretical Quantiles', size=20, labelpad=12.5)
    axs[0][1].set_ylabel('Ordered Values', size=20)
    axs[1][1].set_xlabel('Theoretical Quantiles', size=20, labelpad=12.5)
    axs[1][1].set_ylabel('Ordered Values', size=20)
    for i in range(2):
        for j in range(2):
            axs[i][j].tick_params(axis='x', labelsize=15)
            axs[i][j].tick_params(axis='y', labelsize=15)

    axs[0][0].set_title(example +' of distribution', size=25, y=1.05)
    axs[0][1].set_title(example +' Probability Plot', size=25, y=1.05)
    axs[1][0].set_title('Distribution of '+ example + ' After box-cox Transformation', size=25, y=1.05)
    axs[1][1].set_title(example +' Probability Plot After box-cox Transformation', size=25, y=1.05)
    plt.show();
    print('Box-Cox Promo_depth Skew: {}'.format(df[example].skew()));
    print('Box-Cox Promo_depth Kurtosis: {}'.format(df[example].kurt()));
box_cox('Sales',0.05)
# Out:
# Original Sales to Market Skew: 3.133769637285068
# Original Excess sales to Market Kurtosis: 19.976237171682147
#
# Skew in numerical features:
#
# There are 5 skewed numerical features to Box Cox transform
# Box-Cox Promo_depth Skew: -0.3136968455936036
# Box-Cox Promo_depth Kurtosis: -0.017660487943161662

# %%
numeric_feats = df.dtypes[df.dtypes == "float"].index

# Check the skew of all numerical features
skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(120)
# Out:
# Skew in numerical features:
#                         Skew
# Excess_sales_sub    5.950974
# Excess_sales_mkt    5.929002
# price_per_unit_mkt  1.177698
# Promo_depth         0.699507
# base_price1         0.359304
# price_per_unit      0.303680
# weight              0.279649
# price_per_kg        0.220989
# price_per_unit_sub -0.129572
# Sales              -0.313671
# distribution       -2.017044

# %%
#def scale(col_names,df):
    # scaling numerical values
    #Locate the attribute we need to standardize
#    features = df[col_names]
    # Use scaler of choice; here Standard scaler is used
#    scaler = StandardScaler().fit(features.values)
#    df[col_names] = scaler.transform(features.values)
#col_name = ['Sales','distribution','price_per_unit','base_price1','Promo_depth']
#for i in col_name:
#    scale(col_name,df)

# %%
df.to_csv("/project/data_for_models/feature_eng4.csv")

# %%
df.head()
# Out:
#                                   full_name                          brand  \
# 1  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  MCVITIES CHOCOLATE DIGESTIVES
# 2  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  MCVITIES CHOCOLATE DIGESTIVES
# 3  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  MCVITIES CHOCOLATE DIGESTIVES
# 4  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  MCVITIES CHOCOLATE DIGESTIVES
# 5  MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  MCVITIES CHOCOLATE DIGESTIVES
#
#      company Subsegment         flavour pack_type  weight        channel  \
# 1  PLADIS UK        EDT  MILK CHOCOLATE    SINGLE   266.0  Tesco Express
# 2  PLADIS UK        EDT  MILK CHOCOLATE    SINGLE   266.0  Tesco Express
# 3  PLADIS UK        EDT  MILK CHOCOLATE    SINGLE   266.0  Tesco Express
# 4  PLADIS UK        EDT  MILK CHOCOLATE    SINGLE   266.0  Tesco Express
# 5  PLADIS UK        EDT  MILK CHOCOLATE    SINGLE   266.0  Tesco Express
#
#   retailer   format  ... promo  Cum.promo.total  base_price1  Promo_depth  \
# 1    Tesco  Express  ...     1                2        1.578     0.314544
# 2    Tesco  Express  ...     1                3        1.578     0.314544
# 3    Tesco  Express  ...     1                4        1.578     0.220026
# 4    Tesco  Express  ...     0                0        1.578     0.000000
# 5    Tesco  Express  ...     0                0        1.578     0.000000
#
#       covid  seasons  price_per_unit_mkt  price_per_unit_sub  \
# 1  No Covid   Summer            0.707583            0.847653
# 2  No Covid   Summer            0.707631            0.862829
# 3  No Covid   Summer            0.707964            0.905991
# 4  No Covid   Summer            0.703708            0.924272
# 5  No Covid   Summer            0.705315            0.924476
#
#    Excess_sales_mkt  Excess_sales_sub
# 1          0.444793          0.368744
# 2         -0.002885          0.071862
# 3         -0.329823         -0.336462
# 4         -0.246021         -0.270758
# 5         -0.110773         -0.093103
#
# [5 rows x 28 columns]

# %% [markdown]
# # categorical encoding methods

# %%
import category_encoders as ce

# %%
df = pd.read_csv("/project/data_for_models/feature_eng4.csv",index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18498 entries, 1 to 18982
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   full_name           18498 non-null  object
#  1   brand               18498 non-null  object
#  2   company             18498 non-null  object
#  3   Subsegment          18498 non-null  object
#  4   flavour             18498 non-null  object
#  5   pack_type           18498 non-null  object
#  6   weight              18498 non-null  float64
#  7   channel             18498 non-null  object
#  8   retailer            18498 non-null  object
#  9   format              18498 non-null  object
#  10  date                18498 non-null  object
#  11  Year                18498 non-null  int64
#  12  WeekOfYear          18498 non-null  int64
#  13  Month               18498 non-null  int64
#  14  Sales               18498 non-null  float64
#  15  distribution        18498 non-null  float64
#  16  price_per_kg        18498 non-null  float64
#  17  price_per_unit      18498 non-null  float64
#  18  promo               18498 non-null  int64
#  19  Cum.promo.total     18498 non-null  int64
#  20  base_price1         18498 non-null  float64
#  21  Promo_depth         18498 non-null  float64
#  22  covid               18498 non-null  object
#  23  seasons             18498 non-null  object
#  24  price_per_unit_mkt  18498 non-null  float64
#  25  price_per_unit_sub  18498 non-null  float64
#  26  Excess_sales_mkt    18498 non-null  float64
#  27  Excess_sales_sub    18498 non-null  float64
# dtypes: float64(11), int64(5), object(12)
# memory usage: 4.1+ MB

# %%
# label encoding covid level of restrictions
df.loc[(df.covid == 'No Covid'),'covid']=0
df.loc[(df.covid == 'prior to lockdown'),'covid']=1
df.loc[(df.covid == '1st lockdown'),'covid']=3
df.loc[(df.covid == 'easing period'),'covid']=2
df.loc[(df.covid == '2nd lockdown'),'covid']=3
df['covid'] = df['covid'].astype(str).astype(int)

# %% [markdown]
# ## Encoding cyclic features

# %%
df['mnth_sin'] = np.sin((df.Month-1)*(2.*np.pi/12))
df['mnth_cos'] = np.cos((df.Month-1)*(2.*np.pi/12))
df['wk_sin'] = np.sin((df.WeekOfYear-1)*(2.*np.pi/52))
df['wk_cos'] = np.cos((df.WeekOfYear-1)*(2.*np.pi/52))

# %%
df = df.drop(['Month','WeekOfYear','price_per_kg'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18498 entries, 1 to 18982
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   full_name           18498 non-null  object
#  1   brand               18498 non-null  object
#  2   company             18498 non-null  object
#  3   Subsegment          18498 non-null  object
#  4   flavour             18498 non-null  object
#  5   pack_type           18498 non-null  object
#  6   weight              18498 non-null  float64
#  7   channel             18498 non-null  object
#  8   retailer            18498 non-null  object
#  9   format              18498 non-null  object
#  10  date                18498 non-null  object
#  11  Year                18498 non-null  int64
#  12  Sales               18498 non-null  float64
#  13  distribution        18498 non-null  float64
#  14  price_per_unit      18498 non-null  float64
#  15  promo               18498 non-null  int64
#  16  Cum.promo.total     18498 non-null  int64
#  17  base_price1         18498 non-null  float64
#  18  Promo_depth         18498 non-null  float64
#  19  covid               18498 non-null  int64
#  20  seasons             18498 non-null  object
#  21  price_per_unit_mkt  18498 non-null  float64
#  22  price_per_unit_sub  18498 non-null  float64
#  23  Excess_sales_mkt    18498 non-null  float64
#  24  Excess_sales_sub    18498 non-null  float64
#  25  mnth_sin            18498 non-null  float64
#  26  mnth_cos            18498 non-null  float64
#  27  wk_sin              18498 non-null  float64
#  28  wk_cos              18498 non-null  float64
# dtypes: float64(14), int64(4), object(11)
# memory usage: 4.2+ MB

# %%
df.to_csv("/project/data_for_models/feature_eng5.csv")

# %% [markdown]
# # ignoring the curse of dimentionality

# %%
df_cursed = pd.read_csv("/project/data_for_models/feature_eng5.csv",index_col=0)

# %%
# one-hot encode seasons
cat_var_to_enc = ['seasons','Subsegment','Year','channel']

for var in cat_var_to_enc:
    df = pd.concat([df,\
                          pd.get_dummies(df[var],\
                                         prefix=var, prefix_sep='_', drop_first=False)], axis=1)
df = df.drop(['seasons','Subsegment','Year','retailer','format','channel'],axis=1)

# %%
# one-hot encode seasons
cat_var_to_enc = ['flavour','pack_type']

for var in cat_var_to_enc:
    df_cursed = pd.concat([df_cursed,\
                          pd.get_dummies(df_cursed[var],\
                                         prefix=var, prefix_sep='_', drop_first=False)], axis=1)
df_cursed = df_cursed.drop(['brand','flavour','pack_type'],axis=1)

# %%
# one-hot encode seasons
cat_var_to_enc = ['full_name']

for var in cat_var_to_enc:
    df_cursed = pd.concat([df_cursed,\
                          pd.get_dummies(df_cursed[var],\
                                         prefix=var, prefix_sep='_', drop_first=False)], axis=1)
df_cursed = df_cursed.drop(['full_name'],axis=1)

# %%
Target1 = df_cursed['Excess_sales_mkt']
Target2 = df_cursed['Excess_sales_sub']
Target1.to_csv("/project/data_for_models/Target_mkt.csv")
Target2.to_csv("/project/data_for_models/Target_sub.csv")
df_cursed = df_cursed.drop(['Sales','company','date','Excess_sales_mkt','Excess_sales_sub'],axis=1)
df_cursed.to_csv("/project/data_for_models/feature_eng_cursed.csv")

# %% [markdown]
# # Solution to the curse of dimensionality 1

# %% [markdown]
# ## Clustering

# %%
from sklearn import linear_model
import statsmodels.api as sm

# %% [markdown]
# grouping skus with similar consumer behaviours e.g., similar price elasiticity by clustering; thus skus can be packed into different clusters and hence the dimentions can be reduced through modeling on those clusters instead of the individual skus.

# %% [markdown]
# ### Price Elasticity

# %%
df_solution1 = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df_solution1['weight'] = df_solution1['weight'].str.replace(r'GM$', '')
df_solution1['weight'] = df_solution1['weight'].astype(str).astype(float)
df_solution1['units'] = df_solution1['Sales']/df_solution1['price_per_unit']
df_solution1['price_per_unit_sub_log'] = np.log(df_solution1['price_per_unit_sub'])
df_solution1['units_log'] = np.log(df_solution1['units'])
df_solution1['price_per_unit_log'] = np.log(df_solution1['price_per_unit'])
df_solution1['sub_share'] = (df_solution1['Sales'])/(df_solution1['sub_index'])

channel1 = df_solution1['channel'].drop_duplicates().values.tolist()
channel2 = ['Tesco Express', 'Tesco excl. Express']

sku = df_solution1.groupby(['full_name'], as_index=False)['date'].count()
channel_i = sku.loc[(sku.date >500)]['full_name'].values.tolist()
channel_j = sku.loc[(sku.date <500)]['full_name'].values.tolist()

skus = []
channels = []
price_elasticity = []
r2 = []
Avg_price = []
Avg_sales = []
sub_share = []
Subsegment = []
brand = []
company = []
Excess_sales_sub = []
for i in channel_i:
    for j in channel1:
        reg = linear_model.LinearRegression()
        y= df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'units_log'].values.reshape(-1, 1)
        x = df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'price_per_unit_log'].values.reshape(-1, 1)
        reg.fit(x,y)
        r_sq = reg.score(x, y)
        skus.append(df_solution1.loc[df_solution1['full_name'] == i]['full_name'].drop_duplicates().values.tolist())
        channels.append(df_solution1.loc[df_solution1['channel'] == j]['channel'].drop_duplicates().values.tolist())
        ceo = abs(reg.coef_[0])
        price_elasticity.append(ceo)
        r2.append(r_sq)
        Avg_price.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'price_per_unit'].mean())
        Avg_sales.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Sales'].mean())
        sub_share.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'sub_share'].mean())
        brand.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'brand'].drop_duplicates().values.tolist())
        Subsegment.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Subsegment'].drop_duplicates().values.tolist())
        company.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'company'].drop_duplicates().values.tolist())
        Excess_sales_sub.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Excess_sales_sub'].mean())        
for i in channel_j:
    for j in channel2:
        reg = linear_model.LinearRegression()
        y= df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'units_log'].values.reshape(-1, 1)
        x= df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'price_per_unit_log'].values.reshape(-1, 1)
        reg.fit(x,y)
        r_sq = reg.score(x, y)
        skus.append(df_solution1.loc[df_solution1['full_name'] == i]['full_name'].drop_duplicates().values.tolist())
        channels.append(df_solution1.loc[df_solution1['channel'] == j]['channel'].drop_duplicates().values.tolist())
        ceo = abs(reg.coef_[0])
        price_elasticity.append(ceo)
        r2.append(r_sq)
        Avg_price.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'price_per_unit'].mean())
        Avg_sales.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Sales'].mean())
        sub_share.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'sub_share'].mean())
        brand.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'brand'].drop_duplicates().values.tolist())
        Subsegment.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Subsegment'].drop_duplicates().values.tolist())
        company.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'company'].drop_duplicates().values.tolist())
        Excess_sales_sub.append(df_solution1.loc[(df_solution1.full_name == i)&
                            (df_solution1.channel== j),'Excess_sales_sub'].mean())   
skus = list(chain.from_iterable(skus))
channels = list(chain.from_iterable(channels))
data = {'full_name':skus, "channel":channels,"price_elasticity": price_elasticity,'r2':r2,'sub_share':sub_share,
       "Avg_sales": Avg_sales,"Avg_price": Avg_price,'Subsegment':Subsegment,'company':company,'brand':brand,'Excess_sales_sub':Excess_sales_sub}
# Out:
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()

# %% [markdown]
# Price Elasticity gives the percentage change in quantity demanded in response to a one percent change in price. When you regress the log of volume against log of price, the coefficient gives you the slope i.e. change in volume w.r.t unit change in price.

# %%
df_elas = pd.DataFrame(data)
#df_elas = df_flt.sort_values(by=['price_elasticity'], ascending=False)
df_elas['price_elasticity'] = df_elas['price_elasticity'].str[0]
#df_elas['price_elasticity'] = df_elas['price_elasticity'].str[0]
#df_elas['mkt_share'] = df_elas['mkt_share'].str[0]
df_elas['Subsegment'] = df_elas['Subsegment'].str[0]
df_elas['company'] = df_elas['company'].str[0]
df_elas['brand'] = df_elas['brand'].str[0]
df_elas.loc[df_elas.price_elasticity>10,'price_elasticity']=0
display(HTML(df_elas.to_html()))
df_elas.to_csv("/project/data_for_models/elasticity.csv")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>full_name</th>
#       <th>channel</th>
#       <th>price_elasticity</th>
#       <th>r2</th>
#       <th>sub_share</th>
#       <th>Avg_sales</th>
#       <th>Avg_price</th>
#       <th>Subsegment</th>
#       <th>company</th>
#       <th>brand</th>
#       <th>Excess_sales_sub</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.863774</td>
#       <td>0.888263</td>
#       <td>0.010181</td>
#       <td>33950.886184</td>
#       <td>2.262678</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.134660</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>2.816946</td>
#       <td>0.929037</td>
#       <td>0.020768</td>
#       <td>68880.004605</td>
#       <td>2.240862</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.127946</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>2.065332</td>
#       <td>0.581205</td>
#       <td>0.006036</td>
#       <td>12157.585307</td>
#       <td>2.273783</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.084959</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.032467</td>
#       <td>0.797678</td>
#       <td>0.018002</td>
#       <td>35773.082895</td>
#       <td>1.941171</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.121625</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.677907</td>
#       <td>0.822658</td>
#       <td>0.009139</td>
#       <td>30151.701316</td>
#       <td>1.370658</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.154837</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>2.765100</td>
#       <td>0.885550</td>
#       <td>0.023360</td>
#       <td>77267.226974</td>
#       <td>1.299079</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.118914</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>2.080105</td>
#       <td>0.819979</td>
#       <td>0.004105</td>
#       <td>8181.350658</td>
#       <td>1.582961</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.051558</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>2.702127</td>
#       <td>0.877144</td>
#       <td>0.018904</td>
#       <td>37304.607237</td>
#       <td>1.384711</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.078027</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.790703</td>
#       <td>0.859462</td>
#       <td>0.013897</td>
#       <td>21072.005263</td>
#       <td>1.323296</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.264749</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>3.838639</td>
#       <td>0.848466</td>
#       <td>0.035617</td>
#       <td>54708.257895</td>
#       <td>1.142072</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.179256</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>3.111147</td>
#       <td>0.864407</td>
#       <td>0.006249</td>
#       <td>4891.967763</td>
#       <td>1.422770</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.150284</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.232503</td>
#       <td>0.869355</td>
#       <td>0.044550</td>
#       <td>34424.228289</td>
#       <td>1.296928</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.157589</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Tesco Express</td>
#       <td>3.230072</td>
#       <td>0.874536</td>
#       <td>0.043186</td>
#       <td>69380.627632</td>
#       <td>1.539342</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.235406</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>3.600515</td>
#       <td>0.875897</td>
#       <td>0.077218</td>
#       <td>123170.412500</td>
#       <td>1.543954</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.343222</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>3.332585</td>
#       <td>0.848908</td>
#       <td>0.025505</td>
#       <td>19869.869737</td>
#       <td>1.685289</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.101568</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.062357</td>
#       <td>0.719715</td>
#       <td>0.109680</td>
#       <td>87031.464474</td>
#       <td>1.584158</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.165185</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Tesco Express</td>
#       <td>0.260357</td>
#       <td>0.026145</td>
#       <td>0.023163</td>
#       <td>34933.194079</td>
#       <td>1.099033</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.000173</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Tesco excl. Express</td>
#       <td>0.832708</td>
#       <td>0.147388</td>
#       <td>0.055729</td>
#       <td>83679.264474</td>
#       <td>1.085789</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.000324</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Sainsbury Local</td>
#       <td>1.123534</td>
#       <td>0.375139</td>
#       <td>0.018426</td>
#       <td>15996.942105</td>
#       <td>1.098138</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.001726</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Sainsbury excl Local</td>
#       <td>0.349149</td>
#       <td>0.070579</td>
#       <td>0.074904</td>
#       <td>65109.325000</td>
#       <td>1.090322</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>0.000460</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>
#       <td>Tesco Express</td>
#       <td>2.090981</td>
#       <td>0.374308</td>
#       <td>0.003924</td>
#       <td>5814.380921</td>
#       <td>0.460914</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>-0.000318</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
df_elas = pd.read_csv("/project/data_for_models/elasticity.csv",index_col=0)
df_elas = df_elas.drop(['full_name', 'r2'], axis=1)
df_elas.rename(columns={'sub_share':'Avg. Market Share','Excess_sales_sub':'Excess Sales'}, inplace=True)
sns_plot = sns.pairplot(df_elas, hue='Subsegment', aspect=1.5)
plt.show();
df_elas = df_elas.drop([ "channel",'brand',], axis=1)

sns_plot.savefig("/project/figures/output.png")

# %%
df_elas.loc[(df_elas['Subsegment'] == 'Healthier'),'Subsegment']= 4
df_elas.loc[(df_elas['Subsegment'] == 'CBB'),'Subsegment']= 3
df_elas.loc[(df_elas['Subsegment'] == 'EDT'),'Subsegment']= 2 
df_elas.loc[(df_elas['Subsegment'] == 'EDB'),'Subsegment']= 1

# %%
def clustering(data,x,y,n_clusters,random_state):
    clusters = []
    for i in range(1, 11):
        km = KMeans(n_clusters=i,random_state=random_state).fit(data[[x,y]])
        clusters.append(km.inertia_)

    fig, ax = plt.subplots(figsize=(12, 8))
    sns.lineplot(x=list(range(1, 11)), y=clusters, ax=ax)
    ax.set_title('Searching for Elbow')
    ax.set_xlabel('Clusters')
    ax.set_ylabel('Inertia')

    plt.show();
    
    km3 = KMeans(n_clusters=n_clusters,random_state=random_state).fit(data[[x,y]])
    data['Labels'] = km3.labels_
    plt.figure(figsize=(12, 8))
    sns.scatterplot(data[x], data[y], hue=data['Labels'], 
                    palette=sns.color_palette('hls', n_clusters))
    plt.title('KMeans with '+ str(n_clusters) + ' Clusters')
    plt.show();
    clusters_map = {0:1, 1: 2, 2: 3, 3: 4,4:0}
    data['Labels'] = data['Labels'].map(clusters_map)
    fig = plt.figure(figsize=(20,8))
    ax = fig.add_subplot(121)
    sns.swarmplot(x='Labels', y=x, data=data, ax=ax)
    ax.set_title('Labels According to '+x)

    ax = fig.add_subplot(122)
    sns.swarmplot(x='Labels', y=y, data=data, ax=ax)
    ax.set_title('Labels According to '+y)

    plt.show();

# %%
clustering(df_elas,'price_elasticity','Excess Sales',5,2)

# %% [markdown]
# SKUs under different channels are clustered into 5 clusters by their difference in price elasticity and consumer behavours. Bearing in mind that any price elasticity above 1 is considered as elastic; thus the comparisons of price elasiticy below are based on their relative values. Higher price elasticity meaning consumers are more responsive to price changes, and promos are more likely to be effective, and vice versa.
# - Cluster 0 is mid price elasticity with stable performance and low competition
# - Cluster 1 is high price elasticity with unstable performance and high competition
# - Cluster 2 is very high price elasticity with very unstable performance and very high competition
# - Cluster 3 is extremely high price elasticity with extremely unstable performance and extremely high competition
# - Cluster 4 is price inelastic with stable performance and very low competition

# %%
df_elas_old = pd.read_csv("/project/data_for_models/elasticity.csv",index_col=0)
df_elas_new = df_elas_old.drop(['Avg_sales','Avg_price','r2'], axis=1)
df_elas_new.rename(columns={'sub_share':'Avg. Market Share','Excess_sales_sub':'Excess Sales'}, inplace=True)
df_elas_new = pd.merge(df_elas_new, df_elas[['Labels','Avg. Market Share','Excess Sales']],on=['Excess Sales','Avg. Market Share'])
df_elas_new.rename(columns={'Avg. Market Share':'Market Share'}, inplace=True)
df_elas_new.rename(columns={'Labels':'clusters'}, inplace=True)
#df_elas_new.to_csv("/project/data_for_models/clustered.csv")

# %%
from IPython.core.display import HTML
display(HTML(df_elas_new.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>full_name</th>
#       <th>channel</th>
#       <th>price_elasticity</th>
#       <th>Market Share</th>
#       <th>Subsegment</th>
#       <th>company</th>
#       <th>brand</th>
#       <th>Excess Sales</th>
#       <th>clusters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.863774</td>
#       <td>0.010181</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.134660</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>2.816946</td>
#       <td>0.020768</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.127946</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>2.065332</td>
#       <td>0.006036</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.084959</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BLVT-BRKFST-SFT-BKS CHC-CHPS 50 GM 5 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.032467</td>
#       <td>0.018002</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>BELVITA BREAKFAST SOFT BAKES</td>
#       <td>0.121625</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.677907</td>
#       <td>0.009139</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.154837</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>2.765100</td>
#       <td>0.023360</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.118914</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>2.080105</td>
#       <td>0.004105</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.051558</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>BRS CDBR BRNCH BR CHCLT CHP 32 GM 6 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>2.702127</td>
#       <td>0.018904</td>
#       <td>Healthier</td>
#       <td>MONDELEZ INTERNATIONAL</td>
#       <td>CADBURY BRUNCH BAR</td>
#       <td>0.078027</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Tesco Express</td>
#       <td>2.790703</td>
#       <td>0.013897</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.264749</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>3.838639</td>
#       <td>0.035617</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.179256</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>3.111147</td>
#       <td>0.006249</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.150284</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.232503</td>
#       <td>0.044550</td>
#       <td>CBB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES CLUB</td>
#       <td>0.157589</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Tesco Express</td>
#       <td>3.230072</td>
#       <td>0.043186</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.235406</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Tesco excl. Express</td>
#       <td>3.600515</td>
#       <td>0.077218</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.343222</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Sainsbury Local</td>
#       <td>3.332585</td>
#       <td>0.025505</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.101568</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>BSCT BRS CTD-CBB KT KT ORGNL 21 GM 9 PCK</td>
#       <td>Sainsbury excl Local</td>
#       <td>3.062357</td>
#       <td>0.109680</td>
#       <td>CBB</td>
#       <td>NESTLE ROWNTREE</td>
#       <td>KIT KAT</td>
#       <td>0.165185</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Tesco Express</td>
#       <td>0.260357</td>
#       <td>0.023163</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.000173</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Tesco excl. Express</td>
#       <td>0.832708</td>
#       <td>0.055729</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.000324</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Sainsbury Local</td>
#       <td>1.123534</td>
#       <td>0.018426</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>-0.001726</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL</td>
#       <td>Sainsbury excl Local</td>
#       <td>0.349149</td>
#       <td>0.074904</td>
#       <td>EDB</td>
#       <td>PLADIS UK</td>
#       <td>MCVITIES DIGESTIVES</td>
#       <td>0.000460</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>
#       <td>Tesco Express</td>
#       <td>2.090981</td>
#       <td>0.003924</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>-0.000318</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>
#       <td>Tesco excl. Express</td>
#       <td>0.432917</td>
#       <td>0.016767</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>0.005605</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>
#       <td>Sainsbury Local</td>
#       <td>0.673782</td>
#       <td>0.002414</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>0.003185</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>BSCTS FG RLLS PRVT LBL FG 200 GM SNGL</td>
#       <td>Sainsbury excl Local</td>
#       <td>0.600182</td>
#       <td>0.013792</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>0.011033</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>BSCTS MLTD PRVT LBL MLTD MLK 200 GM SNGL</td>
#       <td>Tesco Express</td>
#       <td>1.325921</td>
#       <td>0.011475</td>
#       <td>EDB</td>
#       <td>PRIVATE LABEL</td>
#       <td>PRIVATE LABEL</td>
#       <td>-0.000501</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>BSCTS MLTD PRVT LBL MLTD MLK 200 GM SNGL</td>
#       <td>Tesco excl. Express</td>
#       <td>0.389918</td>
#       <td>0.031338</td>
#       <td>EDB</td>
#       <td>PRIVATE

# %%
df_elas_new.loc[(df_elas_new.company == 'PLADIS UK')]
# Out:
#                                     full_name               channel  \
# 8      BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK         Tesco Express
# 9      BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK   Tesco excl. Express
# 10     BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK       Sainsbury Local
# 11     BRS CTD-CBB MCVTS-CLB ORNG 22 GM 8 PCK  Sainsbury excl Local
# 16   BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL         Tesco Express
# 17   BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL   Tesco excl. Express
# 18   BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL       Sainsbury Local
# 19   BSCTS DGSTV MCVTS DGSTVS PLN 400 GM SNGL  Sainsbury excl Local
# 28      BSCTS OTS MCVTS-HBNBS PLN 300 GM SNGL         Tesco Express
# 29      BSCTS OTS MCVTS-HBNBS PLN 300 GM SNGL   Tesco excl. Express
# 30      BSCTS OTS MCVTS-HBNBS PLN 300 GM SNGL       Sainsbury Local
# 31      BSCTS OTS MCVTS-HBNBS PLN 300 GM SNGL  Sainsbury excl Local
# 32    BSCTS RCH T MCVTS RCH T PLN 300 GM SNGL         Tesco Express
# 33    BSCTS RCH T MCVTS RCH T PLN 300 GM SNGL   Tesco excl. Express
# 34    BSCTS RCH T MCVTS RCH T PLN 300 GM SNGL       Sainsbury Local
# 35    BSCTS RCH T MCVTS RCH T PLN 300 GM SNGL  Sainsbury excl Local
# 44       GNGR MCVTS GNGR NTS GNGR 250 GM SNGL         Tesco Express
# 45       GNGR MCVTS GNGR NTS GNGR 250 GM SNGL   Tesco excl. Express
# 46       GNGR MCVTS GNGR NTS GNGR 250 GM SNGL       Sainsbury Local
# 47       GNGR MCVTS GNGR NTS GNGR 250 GM SNGL  Sainsbury excl Local
# 48       JFF CKS DRK CHCLT & ORNG 244 GM SNGL         Tesco Express
# 49       JFF CKS DRK CHCLT & ORNG 244 GM SNGL   Tesco excl. Express
# 50       JFF CKS DRK CHCLT & ORNG 244 GM SNGL       Sainsbury Local
# 51       JFF CKS DRK CHCLT & ORNG 244 GM SNGL  Sainsbury excl Local
# 52   MCVTS CHCLT DGSTVS DRK CHCLT 266 GM SNGL         Tesco Express
# 53   MCVTS CHCLT DGSTVS DRK CHCLT 266 GM SNGL   Tesco excl. Express
# 54   MCVTS CHCLT DGSTVS DRK CHCLT 266 GM SNGL       Sainsbury Local
# 55   MCVTS CHCLT DGSTVS DRK CHCLT 266 GM SNGL  Sainsbury excl Local
# 56   MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL         Tesco Express
# 57   MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL   Tesco excl. Express
# 58   MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL       Sainsbury Local
# 59   MCVTS CHCLT DGSTVS MLK CHCLT 266 GM SNGL  Sainsbury excl Local
# 60    MCVTS-CHCLT-HBNBS MLK CHCLT 262 GM SNGL         Tesco Express
# 61    MCVTS-CHCLT-HBNBS MLK CHCLT 262 GM SNGL   Tesco excl. Express
# 62    MCVTS-CHCLT-HBNBS MLK CHCLT 262 GM SNGL       Sainsbury Local
# 63    MCVTS-CHCLT-HBNBS MLK CHCLT 262 GM SNGL  Sainsbury excl Local
# 64         MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK         Tesco Express
# 65         MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK   Tesco excl. Express
# 66         MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK       Sainsbury Local
# 67         MCVTS-PNGN MLK CHCLT 24.6 GM 8 PCK  Sainsbury excl Local
# 116      JFF CKS DRK CHCLT & ORNG 122 GM SNGL         Tesco Express
# 117      JFF CKS DRK CHCLT & ORNG 122 GM SNGL   Tesco excl. Express
#
#      price_elasticity  Market Share Subsegment    company  \
# 8            2.790703      0.013897        CBB  PLADIS UK
# 9            3.838639      0.035617        CBB  PLADIS UK
# 10           3.111147      0.006249        CBB  PLADIS UK
# 11           3.232503      0.044550        CBB  PLADIS UK
# 16           0.260357      0.023163        EDB  PLADIS UK
# 17           0.832708      0.055729        EDB  PLADIS UK
# 18           1.123534      0.018426        EDB  PLADIS UK
# 19           0.349149      0.074904        EDB  PLADIS UK
# 28           2.038652      0.002956        EDB  PLADIS UK
# 29           2.231679      0.014370        EDB  PLADIS UK
# 30           2.129430      0.003165        EDB  PLADIS UK
# 31           1.831335      0.021097        EDB  PLADIS UK
# 32           0.884685      0.017588        EDB  PLADIS UK
# 33           1.175096      0.035696        EDB  PLADIS UK
# 34           1.234648      0.015298        EDB  PLADIS UK
# 35           0.460132      0.055810        EDB  PLADIS UK
# 44           1.511179      0.008639        EDB  PLADIS UK
# 45           1.194951      0.022770        EDB  PLADIS UK
# 46           1.188895      0.009256        EDB  PLADIS UK
# 47           1.670934      0.038871        EDB  PLADIS UK
# 48           3.605372      0.023672        EDT  PLADIS UK
# 49           5.331625      0.043818        EDT  PLADIS UK
# 50           2.685510      0.019311        EDT  PLADIS UK
# 51           4.025670      0.034818        EDT  PLADIS UK
# 52           2.132029      0.008538        EDT  PLADIS UK
# 53           2.697276      0.015603        EDT  PLADIS UK
# 54           2.101134      0.012291        EDT  PLADIS UK
# 55           2.783698      0.030279        EDT  PLADIS UK
# 56           2.657415      0.024725        EDT  PLADIS UK
# 57           3.592444      0.028186        EDT  PLADIS UK
# 58           2.455820      0.022852        EDT  PLADIS UK
# 59           2.843728      0.057061        EDT  PLADIS UK
# 60           2.369275      0.012140        EDT  PLADIS UK
# 61           2.821231      0.019209        EDT  PLADIS UK
# 62           2.566621      0.014131        EDT  PLADIS UK
# 63           2.943981      0.024929        EDT  PLADIS UK
# 64           4.364076      0.014388        CBB  PLADIS UK
# 65           3.810528      0.036583        CBB  PLADIS UK
# 66           2.976066      0.010812        CBB  PLADIS UK
# 67           3.363389      0.053062        CBB  PLADIS UK
# 116          3.181691      0.021604        EDT  PLADIS UK
# 117          3.166286      0.015421        EDT  PLADIS UK
#
#                              brand  Excess Sales  clusters
# 8                    MCVITIES CLUB      0.264749         3
# 9                    MCVITIES CLUB      0.179256         4
# 10                   MCVITIES CLUB      0.150284         3
# 11                   MCVITIES CLUB      0.157589         3
# 16             MCVITIES DIGESTIVES     -0.000173         0
# 17             MCVITIES DIGESTIVES     -0.000324         1
# 18             MCVITIES DIGESTIVES     -0.001726         1
# 19             MCVITIES DIGESTIVES      0.000460         0
# 28                MCVITIES HOBNOBS      0.007416         2
# 29                MCVITIES HOBNOBS      0.003107         2
# 30                MCVITIES HOBNOBS      0.014375         2
# 31                MCVITIES HOBNOBS      0.006326         2
# 32               MCVITIES RICH TEA      0.004095         1
# 33               MCVITIES RICH TEA      0.018803         1
# 34               MCVITIES RICH TEA      0.000222         1
# 35               MCVITIES RICH TEA      0.002569         0
# 44            MCVITIES GINGER NUTS      0.003235         1
# 45            MCVITIES GINGER NUTS      0.002246         1
# 46            MCVITIES GINGER NUTS      0.000721         1
# 47            MCVITIES GINGER NUTS      0.006174         1
# 48            MCVITIES JAFFA CAKES      0.392135         4
# 49            MCVITIES JAFFA CAKES      0.776320         4
# 50            MCVITIES JAFFA CAKES      0.139783         3
# 51            MCVITIES JAFFA CAKES      0.400968         4
# 52   MCVITIES CHOCOLATE DIGESTIVES      0.040564         2
# 53   MCVITIES CHOCOLATE DIGESTIVES      0.081140         3
# 54   MCVITIES CHOCOLATE DIGESTIVES      0.043292         2
# 55   MCVITIES CHOCOLATE DIGESTIVES      0.094126         3
# 56   MCVITIES CHOCOLATE DIGESTIVES      0.086595         3
# 57   MCVITIES CHOCOLATE DIGESTIVES      0.188994         4
# 58   MCVITIES CHOCOLATE DIGESTIVES      0.067445         2
# 59   MCVITIES CHOCOLATE DIGESTIVES      0.102032         3
# 60      MCVITIES CHOCOLATE HOBNOBS      0.043357         2
# 61      MCVITIES CHOCOLATE HOBNOBS      0.085852         3
# 62      MCVITIES CHOCOLATE HOBNOBS      0.101140         3
# 63      MCVITIES CHOCOLATE HOBNOBS      0.115907         3
# 64                MCVITIES PENGUIN      0.244250         4
# 65                MCVITIES PENGUIN      0.126716         4
# 66                MCVITIES PENGUIN      0.155772         3
# 67                MCVITIES PENGUIN      0.195811         3
# 116           MCVITIES JAFFA CAKES      0.240538         3
# 117           MCVITIES JAFFA CAKES      0.230584         3

# %% [markdown]
# ## applying the new clusters

# %%
df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df = df.drop(['mkt_index','sub_index','Sales_p','mkt_index_p','sub_index_p','price_per_unit_mkt'],axis=1)
df = pd.merge(df, df_elas_new[['full_name','channel','price_elasticity','clusters','Market Share']], on=['full_name','channel'], how='left')

# creating new features
df['weight'] = df['weight'].str.replace(r'GM$', '')
df['weight'] = df['weight'].astype(str).astype(float)
df['price_per_kg'] = 1000*df['price_per_unit']/df['weight']

df.rename(columns={'Excess_sales_sub':'Excess Sales'}, inplace=True)
df = df.drop(['Excess_sales_mkt','price_per_unit_sub','Sales','price_per_kg','price_per_unit','price_elasticity'],axis=1)

# %%
df.loc[df.Promo_depth <0,'Promo_depth']
# Out:
# Series([], Name: Promo_depth, dtype: float64)

# %% [markdown]
# ## skewness

# %%
from sklearn.preprocessing import RobustScaler
from statsmodels.graphics.gofplots import qqplot
from scipy import stats
from scipy.stats import norm, skew,probplot #for some statistics
from scipy.special import boxcox1p

# %%
numeric_feats = df.dtypes[df.dtypes == "float"].index

# Check the skew of all numerical features
skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewness = pd.DataFrame({'Skewness' :skewed_feats})
skewness.head(120)
# Out:
#               Skewness
# Excess Sales  5.950974
# Market Share  2.103259
# Promo_depth   0.769974
# base_price1   0.359304
# weight        0.279649
# distribution -2.017044

# %%
def box_cox(example,lam_num):
    fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(16, 16))
    plt.subplots_adjust(top=1.5, right=1.5)
    sns.distplot(df[example].dropna(), hist=True, ax=axs[0][0]);
    probplot(df[example].dropna(), plot=axs[0][1]);
    numeric_feats = df.dtypes[df.dtypes == "float"].index

    # Check the skew of all numerical features
    skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
    skewness = pd.DataFrame({'Skew' :skewed_feats})
#    skewness = skewness[abs(skewness) > 0.75].dropna()
    skewed_features = skewness.index
    for feat in skewed_features:
        #df[feat] += 1
        df[feat] = boxcox1p(df[feat], lam_num)

    sns.distplot(df[example].dropna(), hist=True, ax=axs[1][0]);
    probplot(df[example].dropna(), plot=axs[1][1]);

    axs[0][0].set_xlabel(example +' to Market', size=20, labelpad=12.5)
    axs[1][0].set_xlabel(example +' to Market', size=20, labelpad=12.5)
    axs[0][1].set_xlabel('Theoretical Quantiles', size=20, labelpad=12.5)
    axs[0][0].set_ylabel('Density', size=20)
    axs[0][1].set_ylabel('Ordered Values', size=20)
    axs[1][1].set_xlabel('Theoretical Quantiles', size=20, labelpad=12.5)
    axs[1][0].set_ylabel('Density', size=20)
    axs[1][1].set_ylabel('Ordered Values', size=20)
    for i in range(2):
        for j in range(2):
            axs[i][j].tick_params(axis='x', labelsize=15)
            axs[i][j].tick_params(axis='y', labelsize=15)

    axs[0][0].set_title(example +' of distribution' +' Before Transformation', size=25, y=1.05)
    axs[0][1].set_title(example +' Probability Plot'+' Before Transformation', size=25, y=1.05)
    axs[1][0].set_title('Distribution of '+ example + ' After Box-Cox Transformation', size=25, y=1.05)
    axs[1][1].set_title(example +' Probability Plot After Box-Cox Transformation', size=25, y=1.05)
    plt.show();
box_cox('Excess Sales',0)

# %%
numeric_feats = df.dtypes[df.dtypes == "float"].index

# Check the skew of all numerical features
skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewness1 = pd.DataFrame({'Skewness After Box-Cox Transformation' :skewed_feats})
skewness1.head(120)
# Out:
#               Skewness After Box-Cox Transformation
# Promo_depth                                0.378358
# Market Share                              -0.009822
# base_price1                               -0.038710
# weight                                    -0.181085
# Excess Sales                              -0.521625
# distribution                              -1.144146

# %%
df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df = df.drop(['mkt_index','sub_index','Sales_p','mkt_index_p','sub_index_p','price_per_unit_mkt'],axis=1)
df = pd.merge(df, df_elas_new[['full_name','channel','price_elasticity','clusters','Market Share']], on=['full_name','channel'], how='left')

# creating new features
df['weight'] = df['weight'].str.replace(r'GM$', '')
df['weight'] = df['weight'].astype(str).astype(float)
df['price_per_kg'] = 1000*df['price_per_unit']/df['weight']

df.rename(columns={'Excess_sales_sub':'Excess Sales'}, inplace=True)
df = df.drop(['Excess_sales_mkt','price_per_unit_sub','Sales','price_per_kg','price_per_unit','price_elasticity'],axis=1)

# %%
df['Excess Sales'] = np.log1p(df['Excess Sales'])
df['Promo_depth'] = np.log1p(df['Promo_depth'])
df['base_price1'] = np.log(df['base_price1'])
df['weight'] = np.log(df['weight'])
df['Market Share'] = np.log(df['Market Share'])
df['distribution'] = np.log(df['distribution'])

numeric_feats = df.dtypes[df.dtypes == "float"].index

# Check the skew of all numerical features
skewed_feats = df[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewness2 = pd.DataFrame({'Skewness After Log Transformation' :skewed_feats})
skewness2.head(120)
# Out:
#               Skewness After Log Transformation
# Promo_depth                            0.696086
# Excess Sales                           0.232018
# Market Share                          -0.241231
# weight                                -0.349935
# base_price1                           -0.809013
# distribution                          -2.629697

# %%
skewness = abs(skewness)
skewness1 = abs(skewness1)
skewness2 = abs(skewness2)
skewness['Skewness After Box-Cox Transformation'] = skewness1
skewness['Skewness After Log Transformation'] = skewness2
skewness
# Out:
#               Skewness  Skewness After Box-Cox Transformation  \
# Excess Sales  5.950974                               0.521625
# Market Share  2.103259                               0.009822
# Promo_depth   0.769974                               0.378358
# base_price1   0.359304                               0.038710
# weight        0.279649                               0.181085
# distribution  2.017044                               1.144146
#
#               Skewness After Log Transformation
# Excess Sales                           0.232018
# Market Share                           0.241231
# Promo_depth                            0.696086
# base_price1                            0.809013
# weight                                 0.349935
# distribution                           2.629697

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
df = pd.read_csv("/project/data_for_models/feature_eng3.csv",index_col=0)
df = df.drop(['mkt_index','sub_index','Sales_p','mkt_index_p','sub_index_p','price_per_unit_mkt'],axis=1)
df = pd.merge(df, df_elas_new[['full_name','channel','price_elasticity','clusters','Market Share']], on=['full_name','channel'], how='left')

# creating new features
df['weight'] = df['weight'].str.replace(r'GM$', '')
df['weight'] = df['weight'].astype(str).astype(float)
df['price_per_kg'] = 1000*df['price_per_unit']/df['weight']

df.rename(columns={'Excess_sales_sub':'Excess Sales'}, inplace=True)
df = df.drop(['Excess_sales_mkt','price_per_unit_sub','Sales','price_per_kg','price_per_unit','price_elasticity'],axis=1)

pt = PowerTransformer(method='box-cox')

scaler = MinMaxScaler(feature_range=(0.01, 1))
scaler.fit(df['Excess Sales'].values.reshape(-1, 1))
df['Excess Sales'] = scaler.transform(df['Excess Sales'].values.reshape(-1, 1))
scaler = MinMaxScaler(feature_range=(0.01, 1))
scaler.fit(df['Promo_depth'].values.reshape(-1, 1))
df['Promo_depth'] = scaler.transform(df['Promo_depth'].values.reshape(-1, 1))

df['Excess Sales'] = pt.fit_transform(df['Excess Sales'].values.reshape(-1, 1))
df['Promo_depth'] = pt.fit_transform(df['Promo_depth'].values.reshape(-1, 1))
df['base_price1'] = pt.fit_transform(df['base_price1'].values.reshape(-1, 1))
df['weight'] =pt.fit_transform(df['weight'].values.reshape(-1, 1))
df['Market Share'] = pt.fit_transform(df['Market Share'].values.reshape(-1, 1))
df['distribution'] = pt.fit_transform(df['distribution'].values.reshape(-1, 1))
# Out:
# MinMaxScaler(feature_range=(0.01, 1))
# MinMaxScaler(feature_range=(0.01, 1))

# %% [markdown]
# ## Encoding cyclic features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18498 entries, 0 to 18497
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   full_name        18498 non-null  object
#  1   brand            18498 non-null  object
#  2   company          18498 non-null  object
#  3   Subsegment       18498 non-null  object
#  4   flavour          18498 non-null  object
#  5   pack_type        18498 non-null  object
#  6   weight           18498 non-null  float64
#  7   channel          18498 non-null  object
#  8   retailer         18498 non-null  object
#  9   format           18498 non-null  object
#  10  date             18498 non-null  object
#  11  Year             18498 non-null  int64
#  12  WeekOfYear       18498 non-null  int64
#  13  Month            18498 non-null  int64
#  14  distribution     18498 non-null  float64
#  15  promo            18498 non-null  int64
#  16  Cum.promo.total  18498 non-null  int64
#  17  base_price1      18498 non-null  float64
#  18  Promo_depth      18498 non-null  float64
#  19  covid            18498 non-null  object
#  20  seasons          18498 non-null  object
#  21  Excess Sales     18498 non-null  float64
#  22  clusters         18498 non-null  int64
#  23  Market Share     18498 non-null  float64
# dtypes: float64(6), int64(6), object(12)
# memory usage: 3.5+ MB

# %%
Subsegment_map = {'EDB': 0, 'EDT': 1, 'CBB': 2, 'Healthier': 3}
df['Subsegment'] = df['Subsegment'].map(Subsegment_map)
channel_map = {'Sainsbury Local': 0, 'Sainsbury excl Local': 1, 'Tesco Express': 2, 'Tesco excl. Express': 3}
df['channel'] = df['channel'].map(channel_map)
package_map = {'SINGLE': 1, '3 PACK': 3, '4 PACK': 4, '5 PACK': 5,'6 PACK':6,'8 PACK':8,'9 PACK':9}
df['pack_type'] = df['pack_type'].map(package_map)
df['Year'] = df['Year'].astype(str)
year_map = {'2018': 0, '2019': 1, '2020': 2, '2021': 3}
df['Year'] = df['Year'].map(year_map)
df['Year'] = df['Year'].astype(int)

clusters_map = {0:1, 1: 2, 2: 3, 3: 4,4:0}
df['clusters'] = df['clusters'].map(clusters_map)
#season_map = {'christmas': 0, 'Winter': 1,'Spring': 2, 'Summer': 3, 'Autumn': 4}
#df['seasons'] = df['seasons'].map(season_map)
# label encoding covid level of restrictions
df.loc[(df.covid == 'No Covid'),'covid']=0
df.loc[(df.covid == 'prior to lockdown'),'covid']=1
df.loc[(df.covid == '1st lockdown'),'covid']=3
df.loc[(df.covid == 'easing period'),'covid']=2
df.loc[(df.covid == '2nd lockdown'),'covid']=3
df['covid'] = df['covid'].astype(str).astype(int)
# encoding cyclical
#df['mnth_sin'] = np.sin((df.Month-1)*(2.*np.pi/12))
#df['mnth_cos'] = np.cos((df.Month-1)*(2.*np.pi/12))
#df['wk_sin'] = np.sin((df.WeekOfYear-1)*(2.*np.pi/52))
#df['wk_cos'] = np.cos((df.WeekOfYear-1)*(2.*np.pi/52))
# one-hot encode 
#cat_var_to_enc = ['flavour','seasons']
#for var in cat_var_to_enc:
#    df = pd.concat([df,\
#                          pd.get_dummies(df[var],\
#                                         prefix=var, prefix_sep='_', drop_first=False)], axis=1)
df = df.drop(['WeekOfYear','flavour','format','retailer'],axis=1)
Target3 = df['Market Share']
Target3.to_csv("/project/data_for_models/Target3.csv")
Target2 = df['Excess Sales']
Target2.to_csv("/project/data_for_models/Target2.csv")
df_less_cursed = df.drop(['full_name','company','date','Market Share',
                          'Excess Sales','brand','promo','Cum.promo.total','covid','seasons'],axis=1)
df_less_cursed.to_csv("/project/data_for_models/feature_eng_less_cursed.csv")
df_less_cursed.describe()

display(HTML(df_less_cursed.head(10).to_html()))
# Out:
#          Subsegment     pack_type        weight       channel          Year  \
# count  18498.000000  18498.000000  1.849800e+04  18498.000000  18498.000000
# mean       1.376473      3.149854 -1.287415e-14      1.614283      1.365229
# std        1.133616      2.903734  1.000027e+00      1.112208      0.927394
# min        0.000000      1.000000 -1.420515e+00      0.000000      0.000000
# 25%        0.000000      1.000000 -9.587351e-01      1.000000      1.000000
# 50%        1.000000      1.000000  2.888424e-01      2.000000      1.000000
# 75%        2.000000      5.000000  8.841916e-01      3.000000      2.000000
# max        3.000000      9.000000  1.555876e+00      3.000000      3.000000
#
#               Month  distribution   base_price1   Promo_depth      clusters
# count  18498.000000  1.849800e+04  1.849800e+04  1.849800e+04  18498.000000
# mean       6.559736  2.391319e-15  3.629526e-14 -1.300139e-14      2.694778
# std        3.488754  1.000027e+00  1.000027e+00  1.000027e+00      1.379001
# min        1.000000 -2.065018e+00 -2.212094e+00 -8.331584e-01      0.000000
# 25%        3.000000 -4.574581e-01 -8.493346e-01 -8.331584e-01      2.000000
# 50%        7.000000  5.761525e-01  1.155479e-01 -8.331584e-01      3.000000
# 75%       10.000000  7.372856e-01  7.036066e-01  1.199625e+00      4.000000
# max       12.000000  7.372856e-01  2.134863e+00  1.362652e+00      4.000000
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Subsegment</th>
#       <th>pack_type</th>
#       <th>weight</th>
#       <th>channel</th>
#       <th>Year</th>
#       <th>Month</th>
#       <th>distribution</th>
#       <th>base_price1</th>
#       <th>Promo_depth</th>
#       <th>clusters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0.737286</td>
#       <td>0.104892</td>
#       <td>1.224772</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0.576152</td>
#       <td>0.104892</td>
#       <td>1.224772</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0.576152</td>
#       <td>0.104892</td>
#       <td>1.112574</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0.422787</td>
#       <td>0.104892</td>
#       <td>-0.833158</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>6</td>
#       <td>0.276889</td>
#       <td>0.104892</td>
#       <td>-0.833158</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>0.737286</td>
#       <td>0.104892</td>
#       <td>1.176901</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>0.737286</td>
#       <td>0.104892</td>
#       <td>1.224772</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>0.737286</td>
#       <td>0.104892</td>
#       <td>1.224772</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>7</td>
#       <td>0.737286</td>
#       <td>0.104892</td>
#       <td>1.142407</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.967227</td>
#       <td>2</td>
#       <td>0</td>
#       <td>8</td>
#       <td>0.737286</td>
#       <td>0.115548</td>
#       <td>-0.833158</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
